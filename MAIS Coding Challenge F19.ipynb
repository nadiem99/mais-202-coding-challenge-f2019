# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
homeowner = 'home_ownership_data.csv'
loandata = 'loan_data.csv'

# %%
home = pd.read_csv(homeowner)
data = pd.read_csv(loandata)

# %%
home.set_index('member_id')
data.set_index('member_id')
# Out:
#            loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# member_id
# 1296599         5000         5000       4975.00000   36 months     10.65
# 1314167         2500         2500       2500.00000   60 months     15.27
# 1313524         2400         2400       2400.00000   36 months     15.96
# 1277178        10000        10000      10000.00000   36 months     13.49
# 1311748         3000         3000       3000.00000   60 months     12.69
# 1311441         5000         5000       5000.00000   36 months      7.90
# 1304742         7000         7000       7000.00000   60 months     15.96
# 1288686         3000         3000       3000.00000   36 months     18.64
# 1306957         5600         5600       5600.00000   60 months     21.28
# 1306721         5375         5375       5350.00000   60 months     12.69
# 1305201         6500         6500       6500.00000   60 months     14.65
# 1305008        12000        12000      12000.00000   36 months     12.69
# ...

# %%
loan = pd.merge(home,data,how='outer')
loan
# Out:
#      member_id home_ownership  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1030901       MORTGAGE       8875         8875       8875.00000
# 1      1247741       MORTGAGE       5600         5600       5600.00000
# 2      1261745       MORTGAGE       4375         4375       4375.00000
# 3      1264291           RENT      16000        16000      16000.00000
# 4      1269083           RENT      21000        21000      21000.00000
# 5      1270159       MORTGAGE      21600        21600      20498.26578
# 6      1272024       MORTGAGE       4500         4500       4475.00000
# 7      1273773       MORTGAGE      15000        15000      15000.00000
# 8      1274517           RENT      10000        10000      10000.00000
# 9      1276120           RENT       9200         9200       9200.00000
# 10     1276836           RENT      20000        20000      18590.33777
# 11     1277178           RENT      10000        10000      10000.00000
# ...

# %%
graphdata = pd.DataFrame((loan.groupby('home_ownership').mean()['loan_amnt']))
graphdata
# Out:
#                    loan_amnt
# home_ownership
# MORTGAGE        13502.830189
# OWN              9603.571429
# RENT            11067.481203

# %%
myplot = graphdata.plot(kind='bar',title='Average Loan Amonuts per Home Ownership',)
